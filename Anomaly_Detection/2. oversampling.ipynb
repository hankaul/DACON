# %%
import pandas as pd
import os
import shutil
import time
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/efficientnet/형한결')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_df = pd.read_csv("train_df.csv")
label_list = train_df["label"].unique().tolist()
label_list = sorted(label_list)
len(label_list)  # type = list
# Out:
# 88

# %%
# 폴더 안 파일 개수를 가져오는 함수
def get_num_of_files(directory):
  dirListing = os.listdir(directory)
  return len(dirListing)


# 15개 good 폴더의 파일 개수만 출력해보기
for label in label_list:
  num_files = get_num_of_files(f'train/{label}/')
  if num_files > 50:
    print(num_files)
# Out:
# 209
# 224
# 219
# 280
# 264
# 391
# 245
# 220
# 267
# 320
# 230
# 60
# 213
# 247
# 240

# %% [markdown]
# ### -> good 중의 최솟값인 60에 맞춰서 이상치를 오버샘플링해준다.

# %%
# 이상치 폴더 이름 리스트
anomaly_label_list = []

for label in label_list:
  if label[-4:] != 'good':
    anomaly_label_list.append(label)


len(anomaly_label_list) # 88-15
# Out:
# 73

# %%
# 이상치 폴더 73개에 대해 for loop
# 폴더 내 파일들을 복사하되, 폴더 내 파일 개수가 60개 이상이 되면 stop

for dir in anomaly_label_list:
  current_dir = f'train/{dir}'
  
  original_file_list = []
  for file in os.listdir(current_dir):
    if len(file)== 9:
      original_file_list.append(file)
  
  whole_file_list = os.listdir(current_dir)

  while len(whole_file_list) < 200:
    for file in original_file_list:
      t = float(time.time())
      shutil.copyfile(f'{current_dir}/{file}', f'{current_dir}/{t}-{file}')
    whole_file_list = os.listdir(current_dir)
  
  print(f'{dir} complete')
# Out:
# bottle-broken_large complete
# bottle-broken_small complete
# bottle-contamination complete
# cable-bent_wire complete
# cable-cable_swap complete
# cable-combined complete
# cable-cut_inner_insulation complete
# cable-cut_outer_insulation complete
# cable-missing_cable complete
# cable-missing_wire complete
# cable-poke_insulation complete
# capsule-crack complete
# capsule-faulty_imprint complete
# capsule-poke complete
# capsule-scratch complete
# capsule-squeeze complete
# carpet-color complete
# carpet-cut complete
# carpet-hole complete
# carpet-metal_contamination complete
# carpet-thread complete
# grid-bent complete
# grid-broken complete
# grid-glue complete
# grid-metal_contamination complete
# grid-thread complete
# hazelnut-crack complete
# hazelnut-cut complete
# hazelnut-hole complete
# hazelnut-print complete
# leather-color complete
# leather-cut complete
# leather-fold complete
# leather-glue complete
# leather-poke complete
# metal_nut-bent complete
# metal_nut-color complete
# metal_nut-flip complete
# metal_nut-scratch complete
# pill-color complete
# pill-combined complete
# pill-contamination complete
# pill-crack complete
# pill-faulty_imprint complete
# pill-pill_type complete
# pill-scratch complete
# screw-manipulated_front complete
# screw-scratch_head complete
# screw-scratch_neck complete
# screw-thread_side complete
# screw-thread_top complete
# tile-crack complete
# tile-glue_strip complete
# tile-gray_stroke complete
# tile-oil complete
# tile-rough complete
# toothbrush-defective complete
# transistor-bent_lead complete
# transistor-cut_lead complete
# transistor-damaged_case complete
# transistor-misplaced complete
# wood-color complete
# wood-combined complete
# wood-hole complete
# wood-liquid complete
# wood-scratch complete
# zipper-broken_teeth complete
# zipper-combined complete
# zipper-fabric_border complete
# zipper-fabric_interior complete
# zipper-rough complete
# zipper-split_teeth complete
# zipper-squeezed_teeth complete
